# %%
import os
from glob import glob
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import h5py

import math
import ephem
from datetime import datetime, time, timedelta
from math import pi, cos, sin
from scipy import optimize
from joblib import Parallel, delayed
from mpl_toolkits.basemap import Basemap
# import xesmf as xr

# %run diurnal_utils.py

# %%
save_output_dir = '/export/data1/cchristo/diurnal_analysis_results/'
save_figs_dir = '/home/cchristo/proj_tapio/figs/diurnal_cycle_figs/gpm_2000_2010_precip/'

# %%
# model_dir = '/export/data1/cchristo/gpm_data/gpmdata/'
model_dir = '/export/data1/cchristo/gpm_data/gpmdata_regridded_gfdl_cm4/'

result = [y for x in os.walk(model_dir) for y in glob(os.path.join(x[0], '*.nc'))]
result = sorted(result)

# %%
ds = xr.open_mfdataset(result, combine='nested', concat_dim = 'time')
# ds = xr.open_dataset(result[0],  engine = 'h5netcdf')

# %%
# ds['lon'] = ds['lon'].where(ds['lon'] > 0, ds['lon'] + 360)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (lat: 120, lon: 288, time: 176553)
# Coordinates:
#   * lon               (lon) float64 0.625 1.875 3.125 ... 356.9 358.1 359.4
#   * lat               (lat) float64 -59.5 -58.5 -57.5 -56.5 ... 57.5 58.5 59.5
#   * time              (time) datetime64[ns] 2000-06-01 ... 2010-06-30T23:30:00
# Data variables:
#     precipitationCal  (time, lat, lon) float64 dask.array<chunksize=(1, 120, 288), meta=np.ndarray>
# Attributes:
#     regrid_method:  bilinear

# %%
ds = ds.sel(time = slice('2000-06', '2010-06'))
ds = ds.sel(lat= slice(-60, 60))

# %%
# ds['precipitationCal'].fillna(0)
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (lat: 120, lon: 288, time: 176553)
# Coordinates:
#   * lat               (lat) float64 -59.5 -58.5 -57.5 -56.5 ... 57.5 58.5 59.5
#   * lon               (lon) float64 0.625 1.875 3.125 ... 356.9 358.1 359.4
#   * time              (time) datetime64[ns] 2000-06-01 ... 2010-06-30T23:30:00
# Data variables:
#     precipitationCal  (time, lat, lon) float64 dask.array<chunksize=(1, 120, 288), meta=np.ndarray>
# Attributes:
#     regrid_method:  bilinear

# %%
ds_mean = ds['precipitationCal'].mean(dim = 'time')
ds_mean.load()

# ds_max = ds['precipitationCal'].mean(dim = 'time')
# ds_max.load()
# Out:
# <xarray.DataArray 'precipitationCal' (lat: 120, lon: 288)>
# array([[0.09771565, 0.0970422 , 0.08623457, ..., 0.08471871, 0.09859315,
#         0.09907518],
#        [0.08007466, 0.07755712, 0.07137797, ..., 0.07441439, 0.08160685,
#         0.07971836],
#        [0.07756453, 0.07424548, 0.07045529, ..., 0.06661333, 0.07720636,
#         0.07721252],
#        ...,
#        [0.1587002 , 0.16074525, 0.15478314, ..., 0.11492454, 0.11935249,
#         0.14957255],
#        [0.14685417, 0.15561527, 0.17426882, ..., 0.12822815, 0.13366472,
#         0.1398311 ],
#        [0.14580743, 0.17210521, 0.18888453, ..., 0.14849829, 0.13454499,
#         0.13953332]])
# Coordinates:
#   * lon      (lon) float64 0.625 1.875 3.125 4.375 ... 355.6 356.9 358.1 359.4
#   * lat      (lat) float64 -59.5 -58.5 -57.5 -56.5 -55.5 ... 56.5 57.5 58.5 59.5

# %%
ds_mean.plot.imshow(vmin =0, vmax = 1, cmap = plt.get_cmap('gist_ncar'))
# ds_max.plot.imshow(vmin =0, vmax = 0.25 , cmap = plt.get_cmap('gist_ncar'))

# %%
ds_mean.plot.imshow(vmin =0, vmax = 2, cmap = plt.get_cmap('gist_ncar'))

# %%
ds.isel(time = 0)['precipitationCal'].plot.imshow(vmin =0, vmax = 10)

# %%
ds['precipitationCal']
# Out:
# <xarray.DataArray 'precipitationCal' (lat: 1200, lon: 3600, time: 17520)>
# dask.array<getitem, shape=(1200, 3600, 17520), dtype=float32, chunksize=(1200, 3600, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 -59.95 -59.85 -59.75 -59.65 ... 59.75 59.85 59.95
#   * lon      (lon) float32 180.05 180.15 180.25 180.35 ... 179.75 179.85 179.95
#   * time     (time) datetime64[ns] 2000-06-01 ... 2001-05-31T23:30:00

# %%
mu_season, sigma_season, ampl_season, phase_season = diurnal_analysis(ds, 
                                                                      field_id = 'precipitationCal', 
                                                                      grid_time_resolution_hours = 0.5,
                                                                      time_resolution_hours = 0.5)
# Out:
#   0%|          | 41/43296 [00:00<01:45, 409.71it/s]
# DJF
# 100%|██████████| 43296/43296 [01:17<00:00, 558.07it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:222: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# /home/cchristo/proj_tapio/diurnal_utils.py:240: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# 100%|██████████| 43296/43296 [01:17<00:00, 556.00it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:269: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
#   0%|          | 0/120 [00:00<?, ?it/s]
# Performing Cos Fit
# 100%|██████████| 120/120 [1:16:54<00:00, 38.46s/it]
# Finished Cos Fit
#   0%|          | 57/45600 [00:00<01:21, 561.80it/s]
# JJA
# 100%|██████████| 45600/45600 [01:20<00:00, 565.75it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:222: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# /home/cchristo/proj_tapio/diurnal_utils.py:240: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# 100%|██████████| 45600/45600 [01:21<00:00, 562.05it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:269: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
#   0%|          | 0/120 [00:00<?, ?it/s]
# Performing Cos Fit
# 100%|██████████| 120/120 [1:17:42<00:00, 38.85s/it]
# Finished Cos Fit
#   0%|          | 55/44033 [00:00<01:21, 542.59it/s]
# MAM
# 100%|██████████| 44033/44033 [01:18<00:00, 561.63it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:222: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# /home/cchristo/proj_tapio/diurnal_utils.py:240: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# 100%|██████████| 44033/44033 [01:18<00:00, 559.79it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:269: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
#   0%|          | 0/120 [00:00<?, ?it/s]
# Performing Cos Fit
# 100%|██████████| 120/120 [1:16:31<00:00, 38.27s/it]
# Finished Cos Fit
#   0%|          | 49/43624 [00:00<01:52, 386.28it/s]
# SON
# 100%|██████████| 43624/43624 [01:17<00:00, 562.95it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:222: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# /home/cchristo/proj_tapio/diurnal_utils.py:240: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
# 100%|██████████| 43624/43624 [01:18<00:00, 554.46it/s]
# /home/cchristo/proj_tapio/diurnal_utils.py:269: RuntimeWarning: Mean of empty slice
#   f_bar_k = np.nanmean(masked_field, axis = 0)
#   0%|          | 0/120 [00:00<?, ?it/s]
# Performing Cos Fit
# 100%|██████████| 120/120 [1:14:56<00:00, 37.47s/it]
# Finished Cos Fit

# %%
grid_time_resolution_hours = 0.5
time_resolution_hours = 0.5
field_id = 'precipitationCal'

hour_bins = np.arange(time_resolution_hours, 24 + time_resolution_hours, time_resolution_hours)
grid_hour_bins = np.arange(grid_time_resolution_hours, 24 + grid_time_resolution_hours, grid_time_resolution_hours)

lon_mesh, lat_mesh = np.meshgrid(ds['lon'].values, ds['lat'].values)
ds_seasons = ds.groupby('time.season')

mu_season = {}
sigma_season = {}
ampl_season = {}
phase_season = {}

for season_i, season_ds in ds_seasons:
#         if season_i != 'DJF':
#             break
    print(season_i)
    lst_da = compute_lst_array(season_ds, 
                               bin_interval = grid_time_resolution_hours, # time_resolution_hours,
                               bin_bool = True, 
                               lon_mesh = lon_mesh, 
                               lat_mesh = lat_mesh,
                               field_id = field_id)
    lst_array = lst_da.values
    lst_array[lst_array == 0] = 24
    field_season_array = season_ds[field_id].values

    field_season_mean = field_season_array.mean(axis = 0)

    # compute mu_ij
#         mu_ij = np.zeros(field_season_array.shape[-2:])
    mu_ij = np.zeros(field_season_array.shape[-2:])
#         sigma_ij = np.zeros((len(hour_bins),) + field_season_array.shape[-2:])

    f_bar_ks = {}
    for hour_i in grid_hour_bins:
        masked_field = np.where(lst_array == hour_i, field_season_array, np.nan)

        # mean for a given season, LST
        f_bar_k = np.nanmean(masked_field, axis = 0)
#             f_bar_k[np.isnan(f_bar_k)] = 0
        f_bar_ks[hour_i] = f_bar_k
        mu_ij  += f_bar_k
#             mu_ij_[ii,:,:] = f_bar_k
#         hour_means = np.stack(list(f_bar_ks.values()))
#             plt.imshow(f_bar_k, origin = 'lower')
#             plt.show()

    mu_ij = (1/len(grid_hour_bins))*mu_ij
#         mu_ij = (1/8)*mu_ij
    mu_season[season_i] = mu_ij

    sigma_ij = np.zeros(field_season_array.shape[-2:])
    for hour_i in grid_hour_bins:
        masked_field = np.where(lst_array == hour_i, field_season_array, np.nan)

        # mean for a given season, LST
        f_bar_k = np.nanmean(masked_field, axis = 0)
#             f_bar_k[np.isnan(f_bar_k)] = 0
        sigma_ij += np.square(f_bar_k - mu_ij)

    sigma_ij = np.sqrt((1/(len(grid_hour_bins) - 1))*sigma_ij)
#         sigma_ij = np.sqrt((1/7)*sigma_ij)
#         sigma_ij = np.nanstd(sigma_ij, axis = 0)

    sigma_season[season_i] = sigma_ij

    lst_da = compute_lst_array(season_ds, 
                               bin_interval = time_resolution_hours,
                               bin_bool = True, 
                               lon_mesh = lon_mesh, 
                               lat_mesh = lat_mesh,
                               field_id = field_id)
    lst_array = lst_da.values
    lst_array[lst_array == 0] = 24
    field_season_array = season_ds[field_id].values

    field_season_mean = field_season_array.mean(axis = 0)

    # compute hourly grid means needed for cos fit
    f_bar_ks = {}
    for ii in range(len(hour_bins)):
        hour_i = hour_bins[ii]
        masked_field = np.where(lst_array == hour_i, field_season_array, np.nan)

        # mean for a given season, LST
        f_bar_k = np.nanmean(masked_field, axis = 0)
        f_bar_k[np.isnan(f_bar_k)] = 0
        f_bar_ks[hour_i] = f_bar_k

    hour_means = np.stack(list(f_bar_ks.values()))

    print('Performing Cos Fit')
    res = cos_fit_grid(field_season_array, lst_array, hour_means, hour_bins)
    print('Finished Cos Fit')
    ampl_season[season_i], phase_season[season_i] = res[0], res[1]
# Out:
#   1%|          | 51/4320 [00:00<00:09, 435.89it/s]
# DJF
# 100%|██████████| 4320/4320 [00:07<00:00, 568.56it/s]
# /home/cchristo/.conda/envs/diurnal_research/lib/python3.6/site-packages/ipykernel_launcher.py:42: RuntimeWarning: Mean of empty slice
# /home/cchristo/.conda/envs/diurnal_research/lib/python3.6/site-packages/ipykernel_launcher.py:60: RuntimeWarning: Mean of empty slice
# 100%|██████████| 4320/4320 [00:07<00:00, 569.40it/s]
# /home/cchristo/.conda/envs/diurnal_research/lib/python3.6/site-packages/ipykernel_launcher.py:89: RuntimeWarning: Mean of empty slice
#   0%|          | 0/120 [00:00<?, ?it/s]
# Performing Cos Fit
# 100%|██████████| 120/120 [11:10<00:00,  5.59s/it]
# Finished Cos Fit
#   1%|          | 58/7344 [00:00<00:12, 574.13it/s]
# JJA
#  60%|█████▉    | 4400/7344 [00:07<00:05, 569.87it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-20d452d1999d> in <module>
#      23                                lon_mesh = lon_mesh,
#      24                                lat_mesh = lat_mesh,
# ---> 25                                field_id = field_id)
#      26     lst_array = lst_da.values
#      27     lst_array[lst_array == 0] = 24
#
# ~/proj_tapio/diurnal_utils.py in compute_lst_array(ds, bin_interval, bin_bool, field_id, lon_id, lat_id, time_id, lon_mesh, lat_mesh)
#     171                                                   lon_mesh,
#     172                                                   bin_interval = bin_interval,
# --> 173                                                   bin_bool = bin_bool).astype(int)
#     174
#     175     lst_da = xr.DataArray(lst_times, dims = (time_id, lat_id, lon_id), coords = {time_id:ds[time_id].values,
#
# ~/proj_tapio/diurnal_utils.py in calc_solar_time(utc_time, longitude, bin_interval, bin_bool)
#     136     longitude_radians = np.radians(longitude)
#     137 #     return utc_time + timedelta(hours=longitude_radians / np.pi * 12)
# --> 138     lst_approx = (utc_time.hour + (longitude_radians / np.pi * 12))#%24
#     139     if bin_bool:
#     140 #         return (lst_approx - (lst_approx%3))
#
# KeyboardInterrupt:

# %%
make_four_panel(mu_season , 
#                 cmap = plt.get_cmap('bwr'),
                cmap = plt.get_cmap('gist_ncar'),
                lats = ds['lat'].values, 
                lons = ds['lon'].values,
                vmin = 0,
                vmax = 0.8,
                title = r'$\mu$',
#                 axis = plt.axis([220, 300, 10, 50]), 
                save_fig_path= save_figs_dir + 'GFDL_CM4_means_pr.png')

# %%
make_four_panel(sigma_season , 
                lats = ds['lat'].values, 
                lons = ds['lon'].values,
                vmin = 0, vmax = 0.2, 
#                 cmap = plt.get_cmap('bwr'),
                cmap = plt.get_cmap('gist_ncar'),
                title = r'$\sigma$',
#                 axis = plt.axis([220, 300, 10, 50]), 
                save_fig_path= save_figs_dir + 'GFDL_CM4_stds_pr.png')

# %%
make_four_panel(ampl_season , 
                lats = ds['lat'].values, 
                lons = ds['lon'].values,
#                 vmax = 0.00003, 
#                 cmap = plt.get_cmap('bwr'),
                cmap = plt.get_cmap('gist_ncar'),
                title = r'$A$',
                vmin = 0, vmax = 0.2,
#                 axis = plt.axis([220, 300, 10, 50]), 
                save_fig_path= save_figs_dir + 'GFDL_CM4_ampl_pr.png')

# %%
make_four_panel(phase_season , 
                lats = ds['lat'].values, 
                lons = ds['lon'].values,
#                 vmin = 0, vmax = 24, 
                cmap = plt.get_cmap('twilight'),
                title = r'$\Phi$',
#                 axis = plt.axis([220, 300, 10, 50]), 
                save_fig_path= save_figs_dir + 'GFDL_CM4_phase_pr.png')

# %%
out_ds = xr.Dataset()
out_ds['mu_season'] = make_da_from_dict(mu_season, ds)
out_ds['sigma_season'] = make_da_from_dict(sigma_season, ds)
out_ds['ampl_season'] = make_da_from_dict(ampl_season, ds)
out_ds['phase_season'] = make_da_from_dict(phase_season, ds)

# %%
out_ds.to_netcdf(save_output_dir + 'gpm_2000_2010_precip.nc')
