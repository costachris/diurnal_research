# %%
import os
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import math
import ephem
from datetime import datetime, time, timedelta
from math import pi, cos, sin

# %%
model_dirs = ['hfss_mon_historical','hfls_mon_historical','lwp_mon_historical', 'pr_3hr_historical']
path_to_cmip_dirs = '/export/data1/cchristo/cmip6_clouds/'

# %%
model_list = os.listdir(path_to_cmip_dirs)
# print(model_list)
path_to_cmip_files = path_to_cmip_dirs + model_dirs[-1]
file_list = os.listdir(path_to_cmip_files)
for file in file_list: print(file)
# Out:
# pr_3hr_BCC-CSM2-MR_historical_r1i1p1f1_gn_195001010130-195212312230.nc
# pr_3hr_MIROC6_historical_r5i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_MIROC6_historical_r6i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_MIROC6_historical_r2i1p1f1_gn_201301010130-201312312230.nc
# pr_3hr_MIROC6_historical_r3i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_MIROC6_historical_r8i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_MIROC6_historical_r7i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_MRI-ESM2-0_historical_r5i1p1f1_gn_196001010130-196912312230.nc
# pr_3hr_MIROC-ES2L_historical_r2i1p1f2_gn_185001010130-185012312230.nc
# pr_3hr_FGOALS-g3_historical_r3i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_KACE-1-0-G_historical_r2i1p1f1_gr_200001010130-200912302230.nc
# pr_3hr_MIROC-ES2L_historical_r8i1p1f2_gn_185001010130-185012312230.nc
# pr_3hr_MIROC6_historical_r1i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_KACE-1-0-G_historical_r3i1p1f1_gr_199001010130-199912302230.nc
# pr_3hr_NESM3_historical_r5i1p1f1_gn_196001010130-197812312230.nc
# pr_3hr_NESM3_historical_r1i1p1f1_gn_196001010130-197812312230.nc
# pr_3hr_NESM3_historical_r3i1p1f1_gn_196001010130-197812312230.nc
# pr_3hr_NESM3_historical_r2i1p1f1_gn_196001010130-197812312230.nc
# pr_3hr_MIROC-ES2L_historical_r9i1p1f2_gn_185001010130-185012312230.nc
# pr_3hr_CanESM5_historical_r1i1p2f1_gn_185001010130-186012312230.nc
# pr_3hr_FGOALS-g3_historical_r4i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_NESM3_historical_r4i1p1f1_gn_196001010130-197812302230.nc
# pr_3hr_SAM0-UNICON_historical_r1i1p1f1_gn_195001010130-195012312230.nc
# pr_3hr_MIROC-ES2L_historical_r7i1p1f2_gn_185001010130-185012312230.nc
# pr_3hr_FGOALS-g3_historical_r5i1p1f1_gn_185001010130-185012312230.nc
# pr_3hr_KACE-1-0-G_historical_r1i1p1f1_gr_198001010130-198912302230.nc
# pr_3hr_GISS-E2-1-G_historical_r1i1p1f1_gn_185001010130-185912312230.nc
# pr_3hr_MIROC-ES2L_historical_r4i1p1f2_gn_185001010130-185012312230.nc
# pr_3hr_GISS-E2-1-G_historical_r1i1p1f2_gn_185001010130-185912312230.nc
# pr_3hr_MIROC-ES2L_historical_r6i1p1f2_gn_185001010130-185012312230.nc
# pr_3hr_MIROC-ES2L_historical_r5i1p1f2_gn_185001010130-185012312230.nc
# pr_3hr_FGOALS-g3_historical_r6i1p1f1_gn_185001010130-185012312230.nc

# %%
# file_list
file_names_ = os.listdir( path_to_cmip_dirs + model_dirs[0])
hfss_models = set([ii.split('_')[2] for ii in file_names_])

file_names_ = os.listdir( path_to_cmip_dirs + model_dirs[1])
hfls_models = set([ii.split('_')[2] for ii in file_names_])

file_names_ = os.listdir( path_to_cmip_dirs + model_dirs[2])
lwp_models = set([ii.split('_')[2] for ii in file_names_])
# file_names
set.intersection(hfss_models, hfls_models, lwp_models)
# Out:
# {'CESM2',
#  'CESM2-FV2',
#  'CESM2-WACCM',
#  'CESM2-WACCM-FV2',
#  'CanESM5',
#  'CanESM5-CanOE',
#  'MIROC-ES2L'}

# %%
ds = xr.open_dataset(path_to_cmip_dirs + 'download_from_source/GFDL-CM4/' + \
               "pr_3hr_GFDL-CM4_historical_r1i1p1f1_gr1_196001010130-197912312230.nc")

# %%
ds['pr'].isel(time = 20).plot.imshow(vmax = .0005, cmap = plt.get_cmap('gist_ncar'))

# %%
# Explore CMIP6 Files

# %%
path_to_cmip_dirs = '/export/data1/cchristo/cmip6_clouds/download_from_source/'

# %%
model_list = os.listdir(path_to_cmip_dirs)
print(model_list)
path_to_cmip_files = path_to_cmip_dirs + 'GFDL-ESM4/'
file_list = os.listdir(path_to_cmip_files)
for file in file_list: print(file)
# Out:
# ['GFDL-CM4', 'CNRM-CM5', 'GFDL-ESM4', 'IPSL-CM6A']
# clt_Amon_GFDL-ESM4_historical_r1i1p1f1_gr1_185001-194912.nc
# clt_Amon_GFDL-ESM4_historical_r1i1p1f1_gr1_195001-201412.nc

# %%
# ds = xr.open_dataset(path_to_cmip_dirs + )
