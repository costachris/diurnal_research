# %% [markdown]
# # Utilities for calculating CMIP averages, first created to process TOA fluxes.
# # Computes both seasonal and total averages.

# %%
import os
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
# from fetch_model_helper import *
# %run fetch_model_helper.py
import diurnal_config

# %%
start_date = '1985-01'
end_date = '2006-01'

# %%
rel_cmip6_path= '/export/data1/cchristo/CMIP6_radiation/rlut_mon_historical/'
save_output_rel_dir = '/export/data1/cchristo/CMIP6_radiation/averages/time_averages/period/rlut/'

unique_cmip6_models = get_unique_models(rel_cmip6_path)

# %%
print(unique_cmip6_models)
# Out:
# {'SAM0-UNICON', 'MPI-ESM1-2-LR', 'MIROC-ES2L', 'GISS-E2-1-H', 'EC-Earth3-Veg', 'FGOALS-f3-L', 'MPI-ESM-1-2-HAM', 'MRI-ESM2-0', 'CESM2-WACCM-FV2', 'AWI-CM-1-1-MR', 'CESM2-FV2', 'CIESM', 'KACE-1-0-G', 'NorCPM1', 'CNRM-ESM2-1', 'HadGEM3-GC31-MM', 'MPI-ESM1-2-HR', 'IPSL-CM6A-LR', 'EC-Earth3-Veg-LR', 'BCC-CSM2-MR', 'CanESM5', 'CMCC-CM2-SR5', 'ACCESS-CM2', 'MCM-UA-1-0', 'BCC-ESM1', 'EC-Earth3', 'CNRM-CM6-1', 'NorESM2-LM', 'NorESM2-MM', 'HadGEM3-GC31-LL', 'FGOALS-g3', 'CanESM5-CanOE', 'UKESM1-0-LL', 'CAS-ESM2-0', 'CESM2-WACCM', 'TaiESM1', 'GFDL-ESM4', 'NESM3', 'CAMS-CSM1-0', 'CESM2', 'INM-CM4-8', 'E3SM-1-0', 'GISS-E2-1-G', 'FIO-ESM-2-0', 'CNRM-CM6-1-HR', 'E3SM-1-1-ECA', 'INM-CM5-0', 'AWI-ESM-1-1-LR', 'E3SM-1-1', 'ACCESS-ESM1-5', 'MIROC6'}

# %%
# unique_cmip6_models

cmip_rel_dir = rel_cmip6_path

# %%
# def ds_operation(ds):
#     return ds.groupby('time.season').mean()

def ds_operation(ds):
    return ds.mean(dim = 'time')

# %%
# get 
for model_name in diurnal_config.unique_pr_cmip6_models:
        print(model_name)
        save_output_rel_dir_model = save_output_rel_dir + model_name + '/'
        save_output_path = save_output_rel_dir_model + start_date + '_' + end_date + '_mean.nc'
        try: 
            path_to_cmip_files =  get_path_to_desired_model_cmip6(cmip_rel_dir, 
                                                  desired_model= model_name,
                                                  desired_ensemble_member = ('r1i1p1f1', 'r1i1p2f1','r1i1p1f2'),
                                                  desired_grid_types = ('gn', 'gr', 'gr1', 'gr2'))
    #         print(path_to_cmip_files)
            # subset lat/lon and time
            print('Opening data...')
            ds = xr.open_mfdataset(path_to_cmip_files, combine='by_coords')
    #         ds.load()
            ds = ds.sel(time = slice(start_date, end_date))
            ds = ds.sel(lat= slice(-60, 60))

            # compute seasonal/ total time means
    #         seasonal_mean = ds.groupby('time.season').mean()
    #         total_time_mean = ds.mean(dim = 'time')
            ds_mean = ds_operation(ds)

            # make dir for model if it doesn't already exist
            if not os.path.exists(save_output_rel_dir_model):
                os.makedirs(save_output_rel_dir_model)
    #         print(path_to_cmip_files)
            # save
            ds_mean.to_netcdf(save_output_path)
        except Exception as e:
            print('Could not process ', model_name, ' Reason: ', str(e))
# Out:
# ACCESS-CM2
# Opening data...
# ACCESS-ESM1-5
# Opening data...
# AWI-CM-1-1-MR
# Opening data...
# AWI-ESM-1-1-LR
# Opening data...
# BCC-CSM2-MR
# Opening data...
# CMCC-CM2-SR5
# Opening data...
# CNRM-CM6-1
# Opening data...
# CNRM-CM6-1-HR
# Opening data...
# CNRM-ESM2-1
# Opening data...
# CanESM5
# Opening data...
# EC-Earth3
# Opening data...
# EC-Earth3-Veg
# Opening data...
# EC-Earth3-Veg-LR
# Opening data...
# FGOALS-g3
# Opening data...
# GFDL-CM4
# Opening data...
# -------------------------------------------------------------------------
# OSError                                 Traceback (most recent call last)
# <ipython-input-7-584e9f1e6ded> in <module>
#      11         # subset lat/lon and time
#      12         print('Opening data...')
# ---> 13         ds = xr.open_mfdataset(path_to_cmip_files, combine='by_coords')
#      14 #         ds.load()
#      15         ds = ds.sel(time = slice(start_date, end_date))
#
# ~/.conda/envs/diurnal_research/lib/python3.6/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, lock, data_vars, coords, combine, autoclose, parallel, join, attrs_file, **kwargs)
#     876
#     877     if not paths:
# --> 878         raise OSError("no files to open")
#     879
#     880     # If combine='by_coords' then this is unnecessary, but quick.
#
# OSError: no files to open

# %%
# ds_mean
path_to_cmip_files
# Out:
# ['/export/data1/cchristo/CMIP6_radiation/rlut_mon_historical/rlut_Amon_CanESM5_historical_r1i1p1f1_gn_185001-201412.nc']

# %%
total_time_mean
# Out:
# <xarray.Dataset>
# Dimensions:   (bnds: 2, lat: 96, lon: 192)
# Coordinates:
#   * lat       (lat) float64 -59.38 -58.12 -56.88 -55.62 ... 56.88 58.12 59.38
#   * lon       (lon) float64 0.9375 2.812 4.688 6.562 ... 353.4 355.3 357.2 359.1
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (lat, bnds) float64 -60.0 -58.75 -58.75 -57.5 ... 58.75 58.75 60.0
#     lon_bnds  (lon, bnds) float64 0.0 1.875 1.875 3.75 ... 358.1 358.1 360.0
#     rlut      (lat, lon) float32 198.56375 198.54648 ... 210.73323 211.54372

# %%
total_time_mean['rlut'].plot.imshow(cmap = plt.get_cmap('gist_ncar'))

# %%
# path_to_cmip_files
seasonal_mean['rlut'].isel(season = 3).plot.imshow(cmap = plt.get_cmap('gist_ncar'))
